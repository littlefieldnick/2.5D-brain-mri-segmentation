# %%
from brainmri.dataset.stacker import MriStacker
from brainmri.dataset.dataset import *
from brainmri.runner.train import train_model

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import segmentation_models_pytorch as smp

# %%
config = {
     'make_stacks': True,
     'stack_size': 3,
     'data_dir': './data/lgg-mri-segmentation/kaggle_3m/',
     'out_dir': './data/lgg-mri-segmentation/2.5D/StackSize=3',
     'model_out_pth': './models/unet-resnet50_aug_{date}.pth',
     'augmentations': True,
     'epochs': 75,
     'batch_size': 64,
     'lr': 5e-05,
     'optimizer': 'adam',
     'model': 'unet',
     'model_encoder': 'resnet50',
     'model_act': 'sigmoid',
     'encoder_weights': 'imagenet',
     'device': 'cuda',
     'num_classes': 1
}

# %%
stacker = MriStacker(root_dir=config.get("data_dir"),
                         out_dir=config.get("out_dir"),
                         stack_size=config.get("stack_size"))

if config.get("make_stacks"):
    stacker.process_patients()

stacker.gen_train_val_test_split()


preprocessing_fn = get_preprocessing_fn(config.get("model_encoder"), config.get("encoder_weights"))
train_ds = BrainMriSegmentation(stacker.train_df, config.get("stack_size"),
                                transforms=get_augmentations(is_train=True, apply_transforms=config.get("augmentations")),
                                preprocessing=get_preprocessing(preprocessing_fn))
valid_ds = BrainMriSegmentation(stacker.valid_df, config.get("stack_size"),
                                transforms=None, preprocessing=get_preprocessing(preprocessing_fn))

train_dl = get_dataloader(train_ds, bs=config.get("batch_size"))
valid_dl = get_dataloader(valid_ds, bs=config.get("batch_size"))

train_loss, val_loss, train_fscore, val_fscore, train_iou, val_iou  = train_model(config, train_dl, valid_dl)
# Out:
# /home/nlittlefield/.local/lib/python3.6/site-packages/albumentations/augmentations/transforms.py:1741: UserWarning: Using lambda is incompatible with multiprocessing. Consider using regular functions or partial().
#   warnings.warn('Using lambda is incompatible with multiprocessing. '
# Training unet w/ resnet50 backbone
# Let's use 2 GPUs!
#
# Epoch: 0
# train: 100%|██████████| 37/37 [00:16<00:00,  2.76it/s, dice_loss - 0.9268, iou_score - 0.04125, fscore - 0.07899]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.28it/s, dice_loss - 0.9334, iou_score - 0.05662, fscore - 0.107]
# Model saved!
#
# Epoch: 1
# train: 100%|██████████| 37/37 [00:14<00:00,  2.80it/s, dice_loss - 0.906, iou_score - 0.05654, fscore - 0.1065]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.29it/s, dice_loss - 0.9299, iou_score - 0.09257, fscore - 0.169]
# Model saved!
#
# Epoch: 2
# train: 100%|██████████| 37/37 [00:14<00:00,  2.72it/s, dice_loss - 0.8859, iou_score - 0.09045, fscore - 0.1646]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.21it/s, dice_loss - 0.9258, iou_score - 0.1656, fscore - 0.2832]
# Model saved!
#
# Epoch: 3
# train: 100%|██████████| 37/37 [00:17<00:00,  1.32it/s, dice_loss - 0.8709, iou_score - 0.143, fscore - 0.2485]
# valid: 100%|██████████| 10/10 [00:05<00:00,  2.63it/s, dice_loss - 0.9152, iou_score - 0.3228, fscore - 0.4875]
# Model saved!
#
# Epoch: 4
# train: 100%|██████████| 37/37 [00:15<00:00,  2.72it/s, dice_loss - 0.8545, iou_score - 0.2113, fscore - 0.3458]
# valid: 100%|██████████| 10/10 [00:02<00:00,  3.60it/s, dice_loss - 0.9084, iou_score - 0.4, fscore - 0.5709]
# Model saved!
#
# Epoch: 5
# train: 100%|██████████| 37/37 [00:15<00:00,  2.57it/s, dice_loss - 0.8369, iou_score - 0.2719, fscore - 0.4224]
# valid: 100%|██████████| 10/10 [00:02<00:00,  3.96it/s, dice_loss - 0.9013, iou_score - 0.5145, fscore - 0.6786]
# Model saved!
#
# Epoch: 6
# train: 100%|██████████| 37/37 [00:15<00:00,  2.45it/s, dice_loss - 0.8185, iou_score - 0.3258, fscore - 0.4852]
# valid: 100%|██████████| 10/10 [00:02<00:00,  3.44it/s, dice_loss - 0.8891, iou_score - 0.5122, fscore - 0.6765]
#
# Epoch: 7
# train: 100%|██████████| 37/37 [00:15<00:00,  2.46it/s, dice_loss - 0.8049, iou_score - 0.3449, fscore - 0.5061]
# valid: 100%|██████████| 10/10 [00:02<00:00,  3.96it/s, dice_loss - 0.8687, iou_score - 0.5925, fscore - 0.7432]
# Model saved!
#
# Epoch: 8
# train: 100%|██████████| 37/37 [00:15<00:00,  2.61it/s, dice_loss - 0.7718, iou_score - 0.3923, fscore - 0.5556]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.04it/s, dice_loss - 0.8562, iou_score - 0.5355, fscore - 0.6963]
#
# Epoch: 9
# train: 100%|██████████| 37/37 [00:15<00:00,  2.50it/s, dice_loss - 0.7456, iou_score - 0.4367, fscore - 0.6005]
# valid: 100%|██████████| 10/10 [00:02<00:00,  3.90it/s, dice_loss - 0.8323, iou_score - 0.5529, fscore - 0.7082]
#
# Epoch: 10
# train: 100%|██████████| 37/37 [00:15<00:00,  2.59it/s, dice_loss - 0.7248, iou_score - 0.4439, fscore - 0.6088]
# valid: 100%|██████████| 10/10 [00:02<00:00,  3.97it/s, dice_loss - 0.8166, iou_score - 0.622, fscore - 0.7653]
# Model saved!
#
# Epoch: 11
# train: 100%|██████████| 37/37 [00:15<00:00,  2.61it/s, dice_loss - 0.6911, iou_score - 0.4975, fscore - 0.6589]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.09it/s, dice_loss - 0.792, iou_score - 0.6056, fscore - 0.754]
#
# Epoch: 12
# train: 100%|██████████| 37/37 [00:15<00:00,  2.58it/s, dice_loss - 0.6671, iou_score - 0.5169, fscore - 0.6769]
# valid: 100%|██████████| 10/10 [00:02<00:00,  3.60it/s, dice_loss - 0.7674, iou_score - 0.6405, fscore - 0.7791]
# Model saved!
#
# Epoch: 13
# train: 100%|██████████| 37/37 [00:15<00:00,  2.62it/s, dice_loss - 0.6421, iou_score - 0.5487, fscore - 0.7056]
# valid: 100%|██████████| 10/10 [00:02<00:00,  3.83it/s, dice_loss - 0.7449, iou_score - 0.6808, fscore - 0.8095]
# Model saved!
#
# Epoch: 14
# train: 100%|██████████| 37/37 [00:15<00:00,  2.62it/s, dice_loss - 0.5988, iou_score - 0.5726, fscore - 0.7234]
# valid: 100%|██████████| 10/10 [00:02<00:00,  3.95it/s, dice_loss - 0.7051, iou_score - 0.628, fscore - 0.7706]
#
# Epoch: 15
# train: 100%|██████████| 37/37 [00:14<00:00,  2.62it/s, dice_loss - 0.5723, iou_score - 0.5821, fscore - 0.7291]
# valid: 100%|██████████| 10/10 [00:02<00:00,  3.87it/s, dice_loss - 0.6883, iou_score - 0.6938, fscore - 0.8177]
# Model saved!
#
# Epoch: 16
# train: 100%|██████████| 37/37 [00:14<00:00,  2.64it/s, dice_loss - 0.5541, iou_score - 0.5734, fscore - 0.7238]
# valid: 100%|██████████| 10/10 [00:02<00:00,  3.94it/s, dice_loss - 0.658, iou_score - 0.6451, fscore - 0.7833]
#
# Epoch: 17
# train: 100%|██████████| 37/37 [00:14<00:00,  2.75it/s, dice_loss - 0.5349, iou_score - 0.596, fscore - 0.7435]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.00it/s, dice_loss - 0.6277, iou_score - 0.7549, fscore - 0.8598]
# Model saved!
#
# Epoch: 18
# train: 100%|██████████| 37/37 [00:14<00:00,  2.49it/s, dice_loss - 0.5096, iou_score - 0.5982, fscore - 0.745]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.06it/s, dice_loss - 0.6011, iou_score - 0.7374, fscore - 0.8484]
#
# Epoch: 19
# train: 100%|██████████| 37/37 [00:14<00:00,  2.64it/s, dice_loss - 0.4805, iou_score - 0.6272, fscore - 0.7683]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.06it/s, dice_loss - 0.5666, iou_score - 0.709, fscore - 0.8292]
#
# Epoch: 20
# train: 100%|██████████| 37/37 [00:14<00:00,  2.54it/s, dice_loss - 0.4459, iou_score - 0.6573, fscore - 0.791]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.02it/s, dice_loss - 0.5444, iou_score - 0.7541, fscore - 0.8589]
#
# Epoch: 21
# train: 100%|██████████| 37/37 [00:14<00:00,  2.59it/s, dice_loss - 0.4297, iou_score - 0.6526, fscore - 0.787]
# valid: 100%|██████████| 10/10 [00:02<00:00,  3.98it/s, dice_loss - 0.5172, iou_score - 0.7383, fscore - 0.8491]
#
# Epoch: 22
# train: 100%|██████████| 37/37 [00:14<00:00,  2.70it/s, dice_loss - 0.4068, iou_score - 0.6623, fscore - 0.7936]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.21it/s, dice_loss - 0.4907, iou_score - 0.7806, fscore - 0.8766]
# Model saved!
#
# Epoch: 23
# train: 100%|██████████| 37/37 [00:14<00:00,  2.57it/s, dice_loss - 0.3965, iou_score - 0.6548, fscore - 0.7886]
# valid: 100%|██████████| 10/10 [00:02<00:00,  3.97it/s, dice_loss - 0.4528, iou_score - 0.7522, fscore - 0.858]
#
# Epoch: 24
# train: 100%|██████████| 37/37 [00:14<00:00,  2.72it/s, dice_loss - 0.3684, iou_score - 0.6732, fscore - 0.8026]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.08it/s, dice_loss - 0.4562, iou_score - 0.7465, fscore - 0.8544]
#
# Epoch: 25
# train: 100%|██████████| 37/37 [00:14<00:00,  2.62it/s, dice_loss - 0.3601, iou_score - 0.6519, fscore - 0.7865]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.23it/s, dice_loss - 0.4255, iou_score - 0.7514, fscore - 0.8576]
#
# Epoch: 26
# train: 100%|██████████| 37/37 [00:14<00:00,  2.57it/s, dice_loss - 0.3242, iou_score - 0.6891, fscore - 0.8136]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.18it/s, dice_loss - 0.408, iou_score - 0.7546, fscore - 0.8599]
#
# Epoch: 27
# train: 100%|██████████| 37/37 [00:14<00:00,  2.65it/s, dice_loss - 0.3196, iou_score - 0.6932, fscore - 0.8173]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.21it/s, dice_loss - 0.4005, iou_score - 0.7564, fscore - 0.8607]
#
# Epoch: 28
# train: 100%|██████████| 37/37 [00:14<00:00,  2.65it/s, dice_loss - 0.3068, iou_score - 0.6944, fscore - 0.8176]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.06it/s, dice_loss - 0.3654, iou_score - 0.7779, fscore - 0.8746]
#
# Epoch: 29
# train: 100%|██████████| 37/37 [00:14<00:00,  2.75it/s, dice_loss - 0.291, iou_score - 0.703, fscore - 0.8242]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.11it/s, dice_loss - 0.3385, iou_score - 0.7837, fscore - 0.8783]
# Model saved!
#
# Epoch: 30
# train: 100%|██████████| 37/37 [00:14<00:00,  2.62it/s, dice_loss - 0.2873, iou_score - 0.6969, fscore - 0.8196]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.16it/s, dice_loss - 0.3238, iou_score - 0.7812, fscore - 0.8766]
#
# Epoch: 31
# train: 100%|██████████| 37/37 [00:15<00:00,  2.37it/s, dice_loss - 0.2828, iou_score - 0.6981, fscore - 0.8205]
# valid: 100%|██████████| 10/10 [00:02<00:00,  3.95it/s, dice_loss - 0.3013, iou_score - 0.802, fscore - 0.8897]
# Model saved!
#
# Epoch: 32
# train: 100%|██████████| 37/37 [00:14<00:00,  2.74it/s, dice_loss - 0.2586, iou_score - 0.7242, fscore - 0.8384]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.22it/s, dice_loss - 0.3024, iou_score - 0.8061, fscore - 0.8922]
# Model saved!
#
# Epoch: 33
# train: 100%|██████████| 37/37 [00:14<00:00,  2.79it/s, dice_loss - 0.2588, iou_score - 0.7098, fscore - 0.8276]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.35it/s, dice_loss - 0.2863, iou_score - 0.7907, fscore - 0.8829]
#
# Epoch: 34
# train: 100%|██████████| 37/37 [00:15<00:00,  2.33it/s, dice_loss - 0.2589, iou_score - 0.7004, fscore - 0.822]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.10it/s, dice_loss - 0.2942, iou_score - 0.8015, fscore - 0.8894]
#
# Epoch: 35
# train: 100%|██████████| 37/37 [00:14<00:00,  2.63it/s, dice_loss - 0.2584, iou_score - 0.6935, fscore - 0.816]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.12it/s, dice_loss - 0.2614, iou_score - 0.8022, fscore - 0.8901]
#
# Epoch: 36
# train: 100%|██████████| 37/37 [00:14<00:00,  2.57it/s, dice_loss - 0.2318, iou_score - 0.7289, fscore - 0.8419]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.13it/s, dice_loss - 0.2487, iou_score - 0.8039, fscore - 0.8908]
#
# Epoch: 37
# train: 100%|██████████| 37/37 [00:14<00:00,  2.56it/s, dice_loss - 0.2285, iou_score - 0.7278, fscore - 0.8411]
# valid: 100%|██████████| 10/10 [00:02<00:00,  3.88it/s, dice_loss - 0.2675, iou_score - 0.7705, fscore - 0.87]
#
# Epoch: 38
# train: 100%|██████████| 37/37 [00:14<00:00,  2.76it/s, dice_loss - 0.2274, iou_score - 0.7183, fscore - 0.835]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.19it/s, dice_loss - 0.2509, iou_score - 0.7908, fscore - 0.8828]
#
# Epoch: 39
# train: 100%|██████████| 37/37 [00:14<00:00,  2.63it/s, dice_loss - 0.2194, iou_score - 0.7276, fscore - 0.8411]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.21it/s, dice_loss - 0.2412, iou_score - 0.7861, fscore - 0.8793]
#
# Epoch: 40
# train: 100%|██████████| 37/37 [00:14<00:00,  2.65it/s, dice_loss - 0.214, iou_score - 0.7334, fscore - 0.8439]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.32it/s, dice_loss - 0.2297, iou_score - 0.7994, fscore - 0.8884]
#
# Epoch: 41
# train: 100%|██████████| 37/37 [00:14<00:00,  2.67it/s, dice_loss - 0.2217, iou_score - 0.7156, fscore - 0.8327]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.20it/s, dice_loss - 0.2203, iou_score - 0.8195, fscore - 0.9005]
# Model saved!
#
# Epoch: 42
# train: 100%|██████████| 37/37 [00:14<00:00,  2.67it/s, dice_loss - 0.1994, iou_score - 0.7486, fscore - 0.8554]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.08it/s, dice_loss - 0.2285, iou_score - 0.7854, fscore - 0.8774]
#
# Epoch: 43
# train: 100%|██████████| 37/37 [00:14<00:00,  2.69it/s, dice_loss - 0.2095, iou_score - 0.7249, fscore - 0.838]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.01it/s, dice_loss - 0.2069, iou_score - 0.8023, fscore - 0.8901]
#
# Epoch: 44
# train: 100%|██████████| 37/37 [00:14<00:00,  2.66it/s, dice_loss - 0.2035, iou_score - 0.7322, fscore - 0.844]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.11it/s, dice_loss - 0.1977, iou_score - 0.8073, fscore - 0.8931]
#
# Epoch: 45
# train: 100%|██████████| 37/37 [00:14<00:00,  2.73it/s, dice_loss - 0.2078, iou_score - 0.7213, fscore - 0.8358]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.04it/s, dice_loss - 0.199, iou_score - 0.8046, fscore - 0.8915]
#
# Epoch: 46
# train: 100%|██████████| 37/37 [00:14<00:00,  2.72it/s, dice_loss - 0.2046, iou_score - 0.7264, fscore - 0.8395]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.12it/s, dice_loss - 0.1948, iou_score - 0.8086, fscore - 0.8939]
#
# Epoch: 47
# train: 100%|██████████| 37/37 [00:14<00:00,  2.65it/s, dice_loss - 0.1837, iou_score - 0.7492, fscore - 0.8557]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.13it/s, dice_loss - 0.1999, iou_score - 0.7869, fscore - 0.8798]
#
# Epoch: 48
# train: 100%|██████████| 37/37 [00:14<00:00,  2.67it/s, dice_loss - 0.2059, iou_score - 0.715, fscore - 0.8322]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.12it/s, dice_loss - 0.1872, iou_score - 0.8012, fscore - 0.8892]
#
# Epoch: 49
# train: 100%|██████████| 37/37 [00:14<00:00,  2.58it/s, dice_loss - 0.1957, iou_score - 0.7243, fscore - 0.838]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.25it/s, dice_loss - 0.1804, iou_score - 0.8112, fscore - 0.8953]
#
# Epoch: 50
# train: 100%|██████████| 37/37 [00:14<00:00,  2.69it/s, dice_loss - 0.1832, iou_score - 0.7431, fscore - 0.8518]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.12it/s, dice_loss - 0.1754, iou_score - 0.8075, fscore - 0.8929]
#
# Epoch: 51
# train: 100%|██████████| 37/37 [00:14<00:00,  2.61it/s, dice_loss - 0.1839, iou_score - 0.743, fscore - 0.851]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.13it/s, dice_loss - 0.1743, iou_score - 0.8079, fscore - 0.8933]
#
# Epoch: 52
# train: 100%|██████████| 37/37 [00:14<00:00,  2.70it/s, dice_loss - 0.175, iou_score - 0.75, fscore - 0.856]
# valid: 100%|██████████| 10/10 [00:02<00:00,  3.90it/s, dice_loss - 0.1784, iou_score - 0.8019, fscore - 0.8897]
#
# Epoch: 53
# train: 100%|██████████| 37/37 [00:14<00:00,  2.65it/s, dice_loss - 0.1778, iou_score - 0.7435, fscore - 0.8517]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.19it/s, dice_loss - 0.1768, iou_score - 0.8002, fscore - 0.8885]
#
# Epoch: 54
# train: 100%|██████████| 37/37 [00:14<00:00,  2.62it/s, dice_loss - 0.18, iou_score - 0.7407, fscore - 0.85]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.12it/s, dice_loss - 0.1652, iou_score - 0.809, fscore - 0.8942]
#
# Epoch: 55
# train: 100%|██████████| 37/37 [00:14<00:00,  2.81it/s, dice_loss - 0.1815, iou_score - 0.7358, fscore - 0.8463]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.15it/s, dice_loss - 0.1779, iou_score - 0.7878, fscore - 0.8807]
#
# Epoch: 56
# train: 100%|██████████| 37/37 [00:14<00:00,  2.69it/s, dice_loss - 0.1735, iou_score - 0.7436, fscore - 0.8517]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.10it/s, dice_loss - 0.1685, iou_score - 0.7937, fscore - 0.8844]
#
# Epoch: 57
# train: 100%|██████████| 37/37 [00:14<00:00,  2.69it/s, dice_loss - 0.1628, iou_score - 0.7602, fscore - 0.863]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.21it/s, dice_loss - 0.1674, iou_score - 0.7946, fscore - 0.8851]
#
# Epoch: 58
# train: 100%|██████████| 37/37 [00:14<00:00,  2.66it/s, dice_loss - 0.1556, iou_score - 0.7709, fscore - 0.8695]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.04it/s, dice_loss - 0.1675, iou_score - 0.8016, fscore - 0.8891]
#
# Epoch: 59
# train: 100%|██████████| 37/37 [00:14<00:00,  2.65it/s, dice_loss - 0.1732, iou_score - 0.7432, fscore - 0.8515]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.25it/s, dice_loss - 0.1636, iou_score - 0.7911, fscore - 0.8824]
#
# Epoch: 60
# train: 100%|██████████| 37/37 [00:14<00:00,  2.68it/s, dice_loss - 0.1803, iou_score - 0.7285, fscore - 0.8411]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.10it/s, dice_loss - 0.1562, iou_score - 0.7964, fscore - 0.8863]
#
# Epoch: 61
# train: 100%|██████████| 37/37 [00:14<00:00,  2.72it/s, dice_loss - 0.1876, iou_score - 0.7207, fscore - 0.8362]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.18it/s, dice_loss - 0.1533, iou_score - 0.8029, fscore - 0.8902]
#
# Epoch: 62
# train: 100%|██████████| 37/37 [00:14<00:00,  2.73it/s, dice_loss - 0.1715, iou_score - 0.7386, fscore - 0.8485]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.26it/s, dice_loss - 0.1502, iou_score - 0.8065, fscore - 0.8925]
#
# Epoch: 63
# train: 100%|██████████| 37/37 [00:14<00:00,  2.57it/s, dice_loss - 0.153, iou_score - 0.7677, fscore - 0.8674]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.11it/s, dice_loss - 0.1512, iou_score - 0.8049, fscore - 0.8913]
#
# Epoch: 64
# train: 100%|██████████| 37/37 [00:14<00:00,  2.64it/s, dice_loss - 0.1765, iou_score - 0.7321, fscore - 0.8437]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.10it/s, dice_loss - 0.1546, iou_score - 0.7938, fscore - 0.8829]
#
# Epoch: 65
# train: 100%|██████████| 37/37 [00:14<00:00,  2.63it/s, dice_loss - 0.1603, iou_score - 0.7531, fscore - 0.8578]
# valid: 100%|██████████| 10/10 [00:02<00:00,  3.99it/s, dice_loss - 0.143, iou_score - 0.8141, fscore - 0.897]
#
# Epoch: 66
# train: 100%|██████████| 37/37 [00:14<00:00,  2.69it/s, dice_loss - 0.1734, iou_score - 0.7354, fscore - 0.8445]
# valid: 100%|██████████| 10/10 [00:02<00:00,  3.99it/s, dice_loss - 0.1433, iou_score - 0.8131, fscore - 0.8965]
#
# Epoch: 67
# train: 100%|██████████| 37/37 [00:15<00:00,  2.46it/s, dice_loss - 0.1626, iou_score - 0.7482, fscore - 0.855]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.17it/s, dice_loss - 0.1422, iou_score - 0.8089, fscore - 0.8939]
#
# Epoch: 68
# train: 100%|██████████| 37/37 [00:14<00:00,  2.80it/s, dice_loss - 0.1573, iou_score - 0.7539, fscore - 0.859]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.15it/s, dice_loss - 0.1431, iou_score - 0.8063, fscore - 0.8924]
#
# Epoch: 69
# train: 100%|██████████| 37/37 [00:14<00:00,  2.77it/s, dice_loss - 0.1781, iou_score - 0.7252, fscore - 0.8382]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.25it/s, dice_loss - 0.1387, iou_score - 0.8103, fscore - 0.8949]
#
# Epoch: 70
# train: 100%|██████████| 37/37 [00:14<00:00,  2.73it/s, dice_loss - 0.163, iou_score - 0.7473, fscore - 0.8533]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.27it/s, dice_loss - 0.1415, iou_score - 0.8043, fscore - 0.8912]
#
# Epoch: 71
# train: 100%|██████████| 37/37 [00:14<00:00,  2.78it/s, dice_loss - 0.1546, iou_score - 0.7591, fscore - 0.8613]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.16it/s, dice_loss - 0.1309, iou_score - 0.8198, fscore - 0.9007]
# Model saved!
#
# Epoch: 72
# train: 100%|██████████| 37/37 [00:14<00:00,  2.73it/s, dice_loss - 0.1548, iou_score - 0.7566, fscore - 0.8605]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.26it/s, dice_loss - 0.1344, iou_score - 0.8137, fscore - 0.8971]
#
# Epoch: 73
# train: 100%|██████████| 37/37 [00:14<00:00,  2.80it/s, dice_loss - 0.1509, iou_score - 0.7617, fscore - 0.863]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.29it/s, dice_loss - 0.1294, iou_score - 0.816, fscore - 0.8984]
#
# Epoch: 74
# train: 100%|██████████| 37/37 [00:14<00:00,  2.72it/s, dice_loss - 0.1537, iou_score - 0.7565, fscore - 0.86]
# valid: 100%|██████████| 10/10 [00:02<00:00,  4.25it/s, dice_loss - 0.1324, iou_score - 0.8117, fscore - 0.8953]

# %%
import torch.nn
best_model = torch.load("./models/unet-resnet50_aug_2021-08-23.pth")

# %%
plt.plot(train_loss)
plt.plot(train_fscore)
plt.plot(train_iou)
plt.plot(val_loss)
plt.plot(val_fscore)
plt.plot(val_iou)                                                                                

plt.legend(["Train Loss",  "Train Dice", "Train IoU", "Val Loss", "Val Dice", "Val IoU"])

# %%
test_ds = BrainMriSegmentation(stacker.test_df, config.get("stack_size"),
                                transforms=None, preprocessing=get_preprocessing(preprocessing_fn))
test_dl = get_dataloader(test_ds, bs=config.get("batch_size"))

# %%
loss = smp.utils.losses.DiceLoss()
metrics = [smp.utils.metrics.IoU(threshold=0.5), smp.utils.metrics.Fscore(threshold=0.5)]
    
test_epoch =  smp.utils.train.ValidEpoch(
    best_model,
    loss=loss,
    metrics=metrics,
    device=config.get("device"),
    verbose=True
)

# %%
test_epoch.run(test_dl)
# Out:
# valid: 100%|██████████| 6/6 [00:01<00:00,  4.57it/s, dice_loss - 0.122, iou_score - 0.8057, fscore - 0.8921]
# {'dice_loss': 0.12202962239583333,
#  'iou_score': 0.8057383596897125,
#  'fscore': 0.8921260436375935}
